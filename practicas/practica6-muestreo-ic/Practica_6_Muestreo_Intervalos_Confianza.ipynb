# %% [markdown]
# # Parte 1: Muestreo

# %% [markdown]
# ## Ejercicio 1
#
# El salario $X$, dado en cientos de pesos, de hombres entre 55 y 65 años de cierta ciudad, tiene una distribución normal con $E(X) = 20$ (pesos) y $V(X) = 9$ (pesos cuadrados).

# %% [markdown]
# ## Ejercicio 5
#
# Sea $X \sim N(\mu, \sigma)$ y sea $S^2$ la varianza de muestras aleatorias de $X$ de tamaño 40. Si se sabe que $P(S^2 > 46{,}763) = 0{,}10$, calcular el valor de $\sigma$.

# %% [markdown]
# # Parte 2: Intervalos de Confianza

# %% [markdown]
# ## Ejercicio 13
#
# En un aserradero se cortan varillas de madera cuya longitud es una variable aleatoria con distribución normal. Se miden 25 varillas al azar, obteniéndose $\bar{X} = 180$ cm y $S = 10$ cm. Hallar un intervalo de confianza de nivel 0.95 para la varianza.
